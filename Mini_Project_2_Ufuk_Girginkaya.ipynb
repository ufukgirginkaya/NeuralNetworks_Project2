# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = "dataset.h5"

with h5py.File(filename, "r") as f:
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]
    print(type(f[a_group_key]))
    training_x = np.array(f['trX'])
    training_y = np.array(f['trY'])
    test_x = np.array(f['tstX'])
    test_y = np.array(f['tstY'])
# Out:
# Keys: <KeysViewHDF5 ['trX', 'trY', 'tstX', 'tstY']>
# <class 'h5py._hl.dataset.Dataset'>

# %%
class RecurrentNeuralNetwork_1:
    def __init__(self, input_size, hidden_size, output_size, learning_rate):
        # Hyperparameters
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.output_size = output_size
        # Initialize weights
        self.W_IH = np.random.uniform(-0.1, 0.1, (hidden_size, input_size + 1))
        self.W_HH = np.random.uniform(-0.1, 0.1, (hidden_size, hidden_size))
        self.W_HO = np.random.uniform(-0.1, 0.1, (output_size, hidden_size + 1))

    @staticmethod
    def sigmoid(x):
        return 1 / (1 + np.exp(-x))

    @staticmethod
    def tanh(x):
        return np.tanh(x)

    @staticmethod
    def sigmoid_derivative(x):
        return x * (1 - x)

    @staticmethod
    def tanh_derivative(x):
        return 1 - x**2

    @staticmethod
    def cross_entropy(predictions, targets, epsilon=1e-12):
        predictions = np.clip(predictions, epsilon, 1. - epsilon)
        N = predictions.shape[0]
        ce = -np.sum(targets*np.log(predictions+epsilon))/N
        return ce

    def forward_pass(self, inputs):
        T = inputs.shape[0]  # Sequence length
        self.H = np.zeros((T + 1, self.hidden_size))  # Hidden state initialization with one additional for the initial states bias term
        Y = np.zeros((T, self.output_size))  # Output initialization

        for t in range(T):
            x = np.hstack([inputs[t], [1]])  # Add bias term
            self.H[t] = self.tanh(np.dot(self.W_IH, x) + np.dot(self.W_HH, self.H[t-1]))
            y = self.sigmoid(np.dot(self.W_HO, np.hstack([self.H[t], [1]])))
            Y[t] = y

        return Y

    def train(self, train_x, train_y, epochs, batch_size):
        num_samples, sequence_length, num_features = train_x.shape
        _, num_classes = train_y.shape

        epoch_accuracies = []  # To collect training accuracies at the end of each epoch
        filename = f"training_progress_lr{learning_rate}_bs{batch_size}_hs{hidden_size}.txt"
        with open(filename, "w") as file:
          file.write(f"Learning Rate: {learning_rate}, Batch Size: {batch_size}, Hidden Size: {hidden_size}\n")
          for epoch in range(epochs):
              epoch_loss = 0
              correct_train_predictions = 0

              indices = np.arange(num_samples)
              np.random.shuffle(indices)
              shuffled_train_x = train_x[indices]
              shuffled_train_y = train_y[indices]

              for i in range(0, num_samples, batch_size):
                  batch_end = min(i + batch_size, num_samples)
                  batch_inputs = shuffled_train_x[i:batch_end]
                  batch_targets = shuffled_train_y[i:batch_end]

                  # Reset gradients and hidden states
                  dW_IH, dW_HH, dW_HO = np.zeros_like(self.W_IH), np.zeros_like(self.W_HH), np.zeros_like(self.W_HO)
                  db_H, db_O = np.zeros((self.hidden_size, 1)), np.zeros((self.output_size, 1))
                  h_prev = np.zeros((self.hidden_size, 1))

                  batch_loss = 0

                  for t in range(sequence_length):
                      x = np.hstack([batch_inputs[:, t, :], np.ones((batch_end - i, 1))])  # Add bias term
                      y_true = batch_targets

                      # Forward pass
                      h_prev = np.tanh(np.dot(self.W_IH, x.T) + np.dot(self.W_HH, h_prev))
                      y_pred = self.sigmoid(np.dot(self.W_HO, np.vstack([h_prev, np.ones((1, batch_end - i))])))

                      if t == sequence_length - 1:  # Compute loss
                          batch_loss += np.sum(self.cross_entropy(y_pred.T, y_true))
                          correct_train_predictions += np.sum(np.argmax(y_pred, axis=0) == np.argmax(y_true, axis=1))

                      # Bptt
                      delta_o = (y_pred - y_true.T) * self.sigmoid_derivative(y_pred)
                      dW_HO += np.dot(delta_o, np.vstack([h_prev, np.ones((1, batch_end - i))]).T)
                      delta_h = np.dot(self.W_HO.T, delta_o)[:-1] * self.tanh_derivative(h_prev)

                      dW_HH += np.dot(delta_h, h_prev.T)
                      dW_IH += np.dot(delta_h, x)

                  # Update weights after the batch
                  self.W_IH -= self.learning_rate * dW_IH / sequence_length
                  self.W_HH -= self.learning_rate * dW_HH / sequence_length
                  self.W_HO -= self.learning_rate * dW_HO / sequence_length

                  epoch_loss += batch_loss / (batch_end - i)

              # Average loss and accuracy for the epoch
              epoch_loss /= (num_samples / batch_size)
              train_accuracy = correct_train_predictions / num_samples
              epoch_accuracies.append(train_accuracy)

              file.write(f"Epoch {epoch + 1}, Average Loss: {epoch_loss:.4f}, Training Accuracy: {train_accuracy * 100:.2f}%\n")
              print((f"Epoch {epoch + 1}, Average Loss: {epoch_loss:.4f}, Training Accuracy: {train_accuracy * 100:.2f}%\n"))

          return epoch_accuracies

    def evaluate(self, test_x, test_y, learning_rate, batch_size, hidden_layer_size):
      total_loss = 0
      correct_predictions = 0
      class_correct = dict()
      class_total = dict()

      # filename for each combination of parameters
      filename = f"misclassified_patterns_lr{learning_rate}_bs{batch_size}_hl{hidden_layer_size}.txt"

      with open(filename, "w") as file:
          for i in range(len(test_x)):
              outputs = self.forward_pass(test_x[i])
              total_loss += self.cross_entropy(outputs[-1], test_y[i])
              predicted = np.argmax(outputs[-1])
              actual = np.argmax(test_y[i])

              correct_predictions += int(predicted == actual)

              if actual in class_correct:
                  class_correct[actual] += int(predicted == actual)
              else:
                  class_correct[actual] = int(predicted == actual)

              if actual in class_total:
                  class_total[actual] += 1
              else:
                  class_total[actual] = 1

              # misclassified patterns
              if predicted != actual:
                  file.write(f"Index: {i}, Actual: {actual}, Predicted: {predicted}, Input: {test_x[i]}\n")

      average_loss = total_loss / len(test_x)
      accuracy = correct_predictions / len(test_x) * 100
      per_class_accuracy = {cls: class_correct[cls] / class_total[cls] * 100 for cls in class_correct}

      return average_loss, accuracy, per_class_accuracy

def plot_training_accuracy(epoch_accuracies):
    epochs = range(1, len(epoch_accuracies) + 1)
    plt.figure(figsize=(8, 6))
    plt.plot(epochs, epoch_accuracies, marker='o', linestyle='-')
    plt.title('Training Accuracy vs. Number of Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Training Accuracy')
    plt.grid(True)
    plt.show()

def plot_per_class_accuracy(per_class_accuracy):
    classes = list(per_class_accuracy.keys())
    accuracies = list(per_class_accuracy.values())

    plt.figure(figsize=(10, 6))
    plt.bar(classes, accuracies, align='center', alpha=0.7)
    plt.xlabel('Class')
    plt.ylabel('Accuracy (%)')
    plt.title('Per-Class Accuracy')
    plt.xticks(classes)
    plt.grid(axis='y')
    plt.show()

# %% [markdown]
# Training Progress is recorded in the files:
# training_progress_lr{learning_rate}_bs{batch_size}_hs{hidden_size}.txt

# %%
input_size = 3
output_size = 6

learning_rates = [0.05, 0.1]
hidden_sizes = [50, 100]
batch_sizes = [10, 30]
epochs = 50

for learning_rate in learning_rates:
    for hidden_size in hidden_sizes:
        for batch_size in batch_sizes:
            print('Learning Rate:', learning_rate , ' ' , 'Hidden Size:', hidden_size , ' ' ,'Batch Size:', batch_size)
            rnn = RecurrentNeuralNetwork_1(input_size, hidden_size, output_size, learning_rate)
            epoch_accuracies = rnn.train(training_x, training_y, epochs, batch_size)
            plot_training_accuracy(epoch_accuracies)
            _, accuracy, per_class_accuracy = rnn.evaluate(test_x, test_y,learning_rate, batch_size, hidden_size)
            print(f'The Accuracy is: {accuracy}')
            plot_per_class_accuracy(per_class_accuracy)
            print('------------------------------------------------------------')
# Out:
# Learning Rate: 0.05   Hidden Size: 50   Batch Size: 10
# Epoch 1, Average Loss: 0.1508, Training Accuracy: 33.13%
#
# Epoch 2, Average Loss: 0.1459, Training Accuracy: 40.27%
#
# Epoch 3, Average Loss: 0.1412, Training Accuracy: 43.50%
#
# Epoch 4, Average Loss: 0.1374, Training Accuracy: 46.43%
#
# Epoch 5, Average Loss: 0.1349, Training Accuracy: 47.17%
#
# Epoch 6, Average Loss: 0.1308, Training Accuracy: 48.37%
#
# Epoch 7, Average Loss: 0.1244, Training Accuracy: 50.23%
#
# Epoch 8, Average Loss: 0.1187, Training Accuracy: 52.70%
#
# Epoch 9, Average Loss: 0.1173, Training Accuracy: 53.70%
#
# Epoch 10, Average Loss: 0.1104, Training Accuracy: 56.20%
#
# Epoch 11, Average Loss: 0.1083, Training Accuracy: 57.70%
#
# Epoch 12, Average Loss: 0.1041, Training Accuracy: 59.33%
#
# Epoch 13, Average Loss: 0.1034, Training Accuracy: 59.60%
#
# Epoch 14, Average Loss: 0.1015, Training Accuracy: 61.20%
#
# Epoch 15, Average Loss: 0.0972, Training Accuracy: 62.43%
#
# Epoch 16, Average Loss: 0.0945, Training Accuracy: 62.80%
#
# Epoch 17, Average Loss: 0.0937, Training Accuracy: 63.20%
#
# Epoch 18, Average Loss: 0.0911, Training Accuracy: 64.30%
#
# Epoch 19, Average Loss: 0.0916, Training Accuracy: 63.60%
#
# Epoch 20, Average Loss: 0.0876, Training Accuracy: 65.33%
#
# Epoch 21, Average Loss: 0.0886, Training Accuracy: 65.10%
#
# Epoch 22, Average Loss: 0.0867, Training Accuracy: 65.80%
#
# Epoch 23, Average Loss: 0.0866, Training Accuracy: 66.10%
#
# Epoch 24, Average Loss: 0.0863, Training Accuracy: 66.43%
#
# Epoch 25, Average Loss: 0.0831, Training Accuracy: 67.50%
#
# Epoch 26, Average Loss: 0.0840, Training Accuracy: 68.03%
#
# Epoch 27, Average Loss: 0.0825, Training Accuracy: 68.10%
#
# Epoch 28, Average Loss: 0.0827, Training Accuracy: 67.97%
#
# Epoch 29, Average Loss: 0.0822, Training Accuracy: 68.53%
#
# Epoch 30, Average Loss: 0.0813, Training Accuracy: 68.37%
#
# Epoch 31, Average Loss: 0.0825, Training Accuracy: 68.77%
#
# Epoch 32, Average Loss: 0.0825, Training Accuracy: 68.30%
#
# Epoch 33, Average Loss: 0.0825, Training Accuracy: 69.03%
#
# Epoch 34, Average Loss: 0.0833, Training Accuracy: 69.17%
#
# Epoch 35, Average Loss: 0.0824, Training Accuracy: 69.70%
#
# Epoch 36, Average Loss: 0.0838, Training Accuracy: 69.27%
#
# Epoch 37, Average Loss: 0.0846, Training Accuracy: 69.67%
#
# Epoch 38, Average Loss: 0.0869, Training Accuracy: 68.60%
#
# Epoch 39, Average Loss: 0.0841, Training Accuracy: 69.77%
#
# Epoch 40, Average Loss: 0.0849, Training Accuracy: 70.13%
#
# Epoch 41, Average Loss: 0.0817, Training Accuracy: 70.40%
#
# Epoch 42, Average Loss: 0.0805, Training Accuracy: 70.83%
#
# Epoch 43, Average Loss: 0.0797, Training Accuracy: 71.60%
#
# Epoch 44, Average Loss: 0.0785, Training Accuracy: 72.13%
#
# Epoch 45, Average Loss: 0.0784, Training Accuracy: 71.87%
#
# Epoch 46, Average Loss: 0.0786, Training Accuracy: 72.07%
#
# Epoch 47, Average Loss: 0.0777, Training Accuracy: 72.83%
#
# Epoch 48, Average Loss: 0.0768, Training Accuracy: 73.27%
#
# Epoch 49, Average Loss: 0.0765, Training Accuracy: 72.93%
#
# Epoch 50, Average Loss: 0.0782, Training Accuracy: 71.17%
# The Accuracy is: 69.33333333333334
# ------------------------------------------------------------
# Learning Rate: 0.05   Hidden Size: 50   Batch Size: 30
# Epoch 1, Average Loss: 0.0507, Training Accuracy: 30.67%
#
# Epoch 2, Average Loss: 0.0492, Training Accuracy: 39.60%
#
# Epoch 3, Average Loss: 0.0488, Training Accuracy: 41.53%
#
# Epoch 4, Average Loss: 0.0473, Training Accuracy: 44.47%
#
# Epoch 5, Average Loss: 0.0461, Training Accuracy: 46.07%
#
# Epoch 6, Average Loss: 0.0448, Training Accuracy: 47.73%
#
# Epoch 7, Average Loss: 0.0430, Training Accuracy: 49.40%
#
# Epoch 8, Average Loss: 0.0428, Training Accuracy: 50.63%
#
# Epoch 9, Average Loss: 0.0414, Training Accuracy: 51.70%
#
# Epoch 10, Average Loss: 0.0403, Training Accuracy: 52.40%
#
# Epoch 11, Average Loss: 0.0389, Training Accuracy: 53.43%
#
# Epoch 12, Average Loss: 0.0399, Training Accuracy: 53.00%
#
# Epoch 13, Average Loss: 0.0384, Training Accuracy: 53.77%
#
# Epoch 14, Average Loss: 0.0388, Training Accuracy: 54.63%
#
# Epoch 15, Average Loss: 0.0363, Training Accuracy: 57.43%
#
# Epoch 16, Average Loss: 0.0363, Training Accuracy: 58.13%
#
# Epoch 17, Average Loss: 0.0365, Training Accuracy: 57.60%
#
# Epoch 18, Average Loss: 0.0331, Training Accuracy: 60.93%
#
# Epoch 19, Average Loss: 0.0318, Training Accuracy: 62.00%
#
# Epoch 20, Average Loss: 0.0322, Training Accuracy: 61.40%
#
# Epoch 21, Average Loss: 0.0301, Training Accuracy: 63.80%
#
# Epoch 22, Average Loss: 0.0296, Training Accuracy: 64.07%
#
# Epoch 23, Average Loss: 0.0286, Training Accuracy: 65.23%
#
# Epoch 24, Average Loss: 0.0280, Training Accuracy: 66.50%
#
# Epoch 25, Average Loss: 0.0277, Training Accuracy: 67.90%
#
# Epoch 26, Average Loss: 0.0291, Training Accuracy: 66.97%
#
# Epoch 27, Average Loss: 0.0293, Training Accuracy: 66.93%
#
# Epoch 28, Average Loss: 0.0295, Training Accuracy: 67.40%
#
# Epoch 29, Average Loss: 0.0289, Training Accuracy: 67.00%
#
# Epoch 30, Average Loss: 0.0284, Training Accuracy: 69.47%
#
# Epoch 31, Average Loss: 0.0277, Training Accuracy: 69.40%
#
# Epoch 32, Average Loss: 0.0284, Training Accuracy: 68.23%
#
# Epoch 33, Average Loss: 0.0284, Training Accuracy: 67.80%
#
# Epoch 34, Average Loss: 0.0292, Training Accuracy: 68.77%
#
# Epoch 35, Average Loss: 0.0300, Training Accuracy: 67.87%
#
# Epoch 36, Average Loss: 0.0299, Training Accuracy: 68.47%
#
# Epoch 37, Average Loss: 0.0303, Training Accuracy: 67.83%
#
# Epoch 38, Average Loss: 0.0313, Training Accuracy: 66.93%
#
# Epoch 39, Average Loss: 0.0300, Training Accuracy: 68.93%
#
# Epoch 40, Average Loss: 0.0302, Training Accuracy: 69.23%
#
# Epoch 41, Average Loss: 0.0304, Training Accuracy: 68.10%
#
# Epoch 42, Average Loss: 0.0297, Training Accuracy: 68.67%
#
# Epoch 43, Average Loss: 0.0293, Training Accuracy: 67.40%
#
# Epoch 44, Average Loss: 0.0296, Training Accuracy: 67.53%
#
# Epoch 45, Average Loss: 0.0286, Training Accuracy: 68.93%
#
# Epoch 46, Average Loss: 0.0291, Training Accuracy: 68.83%
#
# Epoch 47, Average Loss: 0.0290, Training Accuracy: 68.07%
#
# Epoch 48, Average Loss: 0.0293, Training Accuracy: 68.20%
#
# Epoch 49, Average Loss: 0.0296, Training Accuracy: 68.47%
#
# Epoch 50, Average Loss: 0.0286, Training Accuracy: 69.80%
# The Accuracy is: 58.166666666666664
# ------------------------------------------------------------
# Learning Rate: 0.05   Hidden Size: 100   Batch Size: 10
# Epoch 1, Average Loss: 0.1501, Training Accuracy: 33.83%
#
# Epoch 2, Average Loss: 0.1470, Training Accuracy: 40.87%
#
# Epoch 3, Average Loss: 0.1430, Training Accuracy: 41.33%
#
# Epoch 4, Average Loss: 0.1390, Training Accuracy: 43.67%
#
# Epoch 5, Average Loss: 0.1354, Training Accuracy: 44.97%
#
# Epoch 6, Average Loss: 0.1334, Training Accuracy: 45.77%
#
# Epoch 7, Average Loss: 0.1311, Training Accuracy: 47.93%
#
# Epoch 8, Average Loss: 0.1238, Training Accuracy: 49.50%
#
# Epoch 9, Average Loss: 0.1201, Training Accuracy: 52.47%
#
# Epoch 10, Average Loss: 0.1168, Training Accuracy: 53.20%
#
# Epoch 11, Average Loss: 0.1145, Training Accuracy: 53.10%
#
# Epoch 12, Average Loss: 0.1123, Training Accuracy: 56.00%
#
# Epoch 13, Average Loss: 0.1052, Training Accuracy: 57.87%
#
# Epoch 14, Average Loss: 0.0987, Training Accuracy: 60.97%
#
# Epoch 15, Average Loss: 0.0987, Training Accuracy: 61.67%
#
# Epoch 16, Average Loss: 0.0936, Training Accuracy: 62.90%
#
# Epoch 17, Average Loss: 0.0911, Training Accuracy: 64.60%
#
# Epoch 18, Average Loss: 0.0891, Training Accuracy: 65.20%
#
# Epoch 19, Average Loss: 0.0867, Training Accuracy: 66.33%
#
# Epoch 20, Average Loss: 0.0850, Training Accuracy: 66.30%
#
# Epoch 21, Average Loss: 0.0823, Training Accuracy: 68.93%
#
# Epoch 22, Average Loss: 0.0822, Training Accuracy: 68.60%
#
# Epoch 23, Average Loss: 0.0815, Training Accuracy: 69.57%
#
# Epoch 24, Average Loss: 0.0807, Training Accuracy: 70.13%
#
# Epoch 25, Average Loss: 0.0805, Training Accuracy: 70.60%
#
# Epoch 26, Average Loss: 0.0788, Training Accuracy: 71.37%
#
# Epoch 27, Average Loss: 0.0772, Training Accuracy: 71.57%
#
# Epoch 28, Average Loss: 0.0757, Training Accuracy: 71.70%
#
# Epoch 29, Average Loss: 0.0748, Training Accuracy: 72.60%
#
# Epoch 30, Average Loss: 0.0733, Training Accuracy: 72.97%
#
# Epoch 31, Average Loss: 0.0765, Training Accuracy: 71.90%
#
# Epoch 32, Average Loss: 0.0737, Training Accuracy: 73.13%
#
# Epoch 33, Average Loss: 0.0747, Training Accuracy: 71.80%
#
# Epoch 34, Average Loss: 0.0742, Training Accuracy: 72.67%
#
# Epoch 35, Average Loss: 0.0763, Training Accuracy: 72.27%
#
# Epoch 36, Average Loss: 0.0737, Training Accuracy: 72.13%
#
# Epoch 37, Average Loss: 0.0768, Training Accuracy: 71.00%
#
# Epoch 38, Average Loss: 0.0751, Training Accuracy: 71.53%
#
# Epoch 39, Average Loss: 0.0750, Training Accuracy: 71.13%
#
# Epoch 40, Average Loss: 0.0760, Training Accuracy: 71.33%
#
# Epoch 41, Average Loss: 0.0996, Training Accuracy: 63.77%
#
# Epoch 42, Average Loss: 0.1128, Training Accuracy: 60.97%
#
# Epoch 43, Average Loss: 0.1064, Training Accuracy: 63.67%
#
# Epoch 44, Average Loss: 0.1006, Training Accuracy: 64.50%
#
# Epoch 45, Average Loss: 0.1279, Training Accuracy: 54.57%
#
# Epoch 46, Average Loss: 0.1525, Training Accuracy: 44.33%
#
# Epoch 47, Average Loss: 0.1600, Training Accuracy: 41.37%
#
# Epoch 48, Average Loss: 0.1758, Training Accuracy: 31.73%
#
# Epoch 49, Average Loss: 0.2008, Training Accuracy: 25.93%
#
# Epoch 50, Average Loss: 0.1902, Training Accuracy: 27.03%
# The Accuracy is: 26.0
# ------------------------------------------------------------
# Learning Rate: 0.05   Hidden Size: 100   Batch Size: 30
# Epoch 1, Average Loss: 0.0508, Training Accuracy: 33.80%
#
# Epoch 2, Average Loss: 0.0501, Training Accuracy: 38.47%
#
# Epoch 3, Average Loss: 0.0491, Training Accuracy: 42.00%
#
# Epoch 4, Average Loss: 0.0484, Training Accuracy: 40.87%
#
# Epoch 5, Average Loss: 0.0468, Training Accuracy: 42.63%
#
# Epoch 6, Average Loss: 0.0455, Training Accuracy: 45.53%
#
# Epoch 7, Average Loss: 0.0442, Training Accuracy: 47.93%
#
# Epoch 8, Average Loss: 0.0422, Training Accuracy: 49.73%
#
# Epoch 9, Average Loss: 0.0413, Training Accuracy: 51.47%
#
# Epoch 10, Average Loss: 0.0399, Training Accuracy: 53.43%
#
# Epoch 11, Average Loss: 0.0403, Training Accuracy: 53.77%
#
# Epoch 12, Average Loss: 0.0372, Training Accuracy: 56.33%
#
# Epoch 13, Average Loss: 0.0355, Training Accuracy: 59.57%
#
# Epoch 14, Average Loss: 0.0331, Training Accuracy: 60.87%
#
# Epoch 15, Average Loss: 0.0312, Training Accuracy: 62.90%
#
# Epoch 16, Average Loss: 0.0305, Training Accuracy: 64.07%
#
# Epoch 17, Average Loss: 0.0310, Training Accuracy: 64.37%
#
# Epoch 18, Average Loss: 0.0306, Training Accuracy: 65.27%
#
# Epoch 19, Average Loss: 0.0298, Training Accuracy: 66.17%
#
# Epoch 20, Average Loss: 0.0298, Training Accuracy: 66.17%
#
# Epoch 21, Average Loss: 0.0301, Training Accuracy: 66.27%
#
# Epoch 22, Average Loss: 0.0292, Training Accuracy: 67.07%
#
# Epoch 23, Average Loss: 0.0286, Training Accuracy: 67.43%
#
# Epoch 24, Average Loss: 0.0285, Training Accuracy: 67.33%
#
# Epoch 25, Average Loss: 0.0278, Training Accuracy: 67.73%
#
# Epoch 26, Average Loss: 0.0275, Training Accuracy: 68.97%
#
# Epoch 27, Average Loss: 0.0288, Training Accuracy: 67.40%
#
# Epoch 28, Average Loss: 0.0278, Training Accuracy: 68.60%
#
# Epoch 29, Average Loss: 0.0284, Training Accuracy: 67.37%
#
# Epoch 30, Average Loss: 0.0296, Training Accuracy: 67.20%
#
# Epoch 31, Average Loss: 0.0281, Training Accuracy: 68.87%
#
# Epoch 32, Average Loss: 0.0284, Training Accuracy: 67.90%
#
# Epoch 33, Average Loss: 0.0279, Training Accuracy: 69.43%
#
# Epoch 34, Average Loss: 0.0282, Training Accuracy: 69.93%
#
# Epoch 35, Average Loss: 0.0286, Training Accuracy: 69.13%
#
# Epoch 36, Average Loss: 0.0282, Training Accuracy: 69.63%
#
# Epoch 37, Average Loss: 0.0271, Training Accuracy: 69.80%
#
# Epoch 38, Average Loss: 0.0266, Training Accuracy: 70.63%
#
# Epoch 39, Average Loss: 0.0282, Training Accuracy: 68.70%
#
# Epoch 40, Average Loss: 0.0551, Training Accuracy: 46.20%
#
# Epoch 41, Average Loss: 0.0629, Training Accuracy: 29.83%
#
# Epoch 42, Average Loss: 0.0670, Training Accuracy: 23.07%
#
# Epoch 43, Average Loss: 0.0594, Training Accuracy: 31.33%
#
# Epoch 44, Average Loss: 0.0576, Training Accuracy: 31.77%
#
# Epoch 45, Average Loss: 0.0687, Training Accuracy: 18.93%
#
# Epoch 46, Average Loss: 0.0769, Training Accuracy: 17.17%
#
# Epoch 47, Average Loss: 0.0750, Training Accuracy: 16.63%
#
# Epoch 48, Average Loss: 0.0683, Training Accuracy: 16.50%
#
# Epoch 49, Average Loss: 0.0697, Training Accuracy: 15.70%
#
# Epoch 50, Average Loss: 0.0716, Training Accuracy: 16.77%
# The Accuracy is: 16.666666666666664
# ------------------------------------------------------------
# Learning Rate: 0.1   Hidden Size: 50   Batch Size: 10
# Epoch 1, Average Loss: 0.1539, Training Accuracy: 34.33%
#
# Epoch 2, Average Loss: 0.1483, Training Accuracy: 42.00%
#
# Epoch 3, Average Loss: 0.1438, Training Accuracy: 44.23%
#
# Epoch 4, Average Loss: 0.1379, Training Accuracy: 46.73%
#
# Epoch 5, Average Loss: 0.1333, Training Accuracy: 48.20%
#
# Epoch 6, Average Loss: 0.1249, Training Accuracy: 51.37%
#
# Epoch 7, Average Loss: 0.1200, Training Accuracy: 54.50%
#
# Epoch 8, Average Loss: 0.1157, Training Accuracy: 56.53%
#
# Epoch 9, Average Loss: 0.1055, Training Accuracy: 60.00%
#
# Epoch 10, Average Loss: 0.1050, Training Accuracy: 61.40%
#
# Epoch 11, Average Loss: 0.1073, Training Accuracy: 60.13%
#
# Epoch 12, Average Loss: 0.1054, Training Accuracy: 61.53%
#
# Epoch 13, Average Loss: 0.1094, Training Accuracy: 58.53%
#
# Epoch 14, Average Loss: 0.1202, Training Accuracy: 56.30%
#
# Epoch 15, Average Loss: 0.1196, Training Accuracy: 56.53%
#
# Epoch 16, Average Loss: 0.1104, Training Accuracy: 59.30%
#
# Epoch 17, Average Loss: 0.1030, Training Accuracy: 61.50%
#
# Epoch 18, Average Loss: 0.1039, Training Accuracy: 62.20%
#
# Epoch 19, Average Loss: 0.1175, Training Accuracy: 58.00%
#
# Epoch 20, Average Loss: 0.1801, Training Accuracy: 35.53%
#
# Epoch 21, Average Loss: 0.1788, Training Accuracy: 32.33%
#
# Epoch 22, Average Loss: 0.1742, Training Accuracy: 34.13%
#
# Epoch 23, Average Loss: 0.1613, Training Accuracy: 36.80%
#
# Epoch 24, Average Loss: 0.1623, Training Accuracy: 36.00%
#
# Epoch 25, Average Loss: 0.1741, Training Accuracy: 33.57%
#
# Epoch 26, Average Loss: 0.1662, Training Accuracy: 38.70%
#
# Epoch 27, Average Loss: 0.1652, Training Accuracy: 38.90%
#
# Epoch 28, Average Loss: 0.1786, Training Accuracy: 32.47%
#
# Epoch 29, Average Loss: 0.1712, Training Accuracy: 35.83%
#
# Epoch 30, Average Loss: 0.1818, Training Accuracy: 32.20%
#
# Epoch 31, Average Loss: 0.1697, Training Accuracy: 34.37%
#
# Epoch 32, Average Loss: 0.1720, Training Accuracy: 30.30%
#
# Epoch 33, Average Loss: 0.1812, Training Accuracy: 20.40%
#
# Epoch 34, Average Loss: 0.1790, Training Accuracy: 18.10%
#
# Epoch 35, Average Loss: 0.1791, Training Accuracy: 18.07%
#
# Epoch 36, Average Loss: 0.1792, Training Accuracy: 17.63%
#
# Epoch 37, Average Loss: 0.1793, Training Accuracy: 16.27%
#
# Epoch 38, Average Loss: 0.1793, Training Accuracy: 17.47%
#
# Epoch 39, Average Loss: 0.1794, Training Accuracy: 17.87%
#
# Epoch 40, Average Loss: 0.1797, Training Accuracy: 16.23%
#
# Epoch 41, Average Loss: 0.1796, Training Accuracy: 17.40%
#
# Epoch 42, Average Loss: 0.1797, Training Accuracy: 17.00%
#
# Epoch 43, Average Loss: 0.1796, Training Accuracy: 17.30%
#
# Epoch 44, Average Loss: 0.1799, Training Accuracy: 15.87%
#
# Epoch 45, Average Loss: 0.1799, Training Accuracy: 15.37%
#
# Epoch 46, Average Loss: 0.1798, Training Accuracy: 17.27%
#
# Epoch 47, Average Loss: 0.1798, Training Accuracy: 16.80%
#
# Epoch 48, Average Loss: 0.1799, Training Accuracy: 17.20%
#
# Epoch 49, Average Loss: 0.1798, Training Accuracy: 15.70%
#
# Epoch 50, Average Loss: 0.1800, Training Accuracy: 16.30%
# The Accuracy is: 16.5
# ------------------------------------------------------------
# Learning Rate: 0.1   Hidden Size: 50   Batch Size: 30
# Epoch 1, Average Loss: 0.0511, Training Accuracy: 35.00%
#
# Epoch 2, Average Loss: 0.0502, Training Accuracy: 41.10%
#
# Epoch 3, Average Loss: 0.0488, Training Accuracy: 43.17%
#
# Epoch 4, Average Loss: 0.0467, Training Accuracy: 45.73%
#
# Epoch 5, Average Loss: 0.0436, Training Accuracy: 49.13%
#
# Epoch 6, Average Loss: 0.0410, Training Accuracy: 52.87%
#
# Epoch 7, Average Loss: 0.0394, Training Accuracy: 56.43%
#
# Epoch 8, Average Loss: 0.0369, Training Accuracy: 57.83%
#
# Epoch 9, Average Loss: 0.0361, Training Accuracy: 59.47%
#
# Epoch 10, Average Loss: 0.0353, Training Accuracy: 60.40%
#
# Epoch 11, Average Loss: 0.0568, Training Accuracy: 36.53%
#
# Epoch 12, Average Loss: 0.0756, Training Accuracy: 17.07%
#
# Epoch 13, Average Loss: 0.0762, Training Accuracy: 15.93%
#
# Epoch 14, Average Loss: 0.0793, Training Accuracy: 15.23%
#
# Epoch 15, Average Loss: 0.0723, Training Accuracy: 15.43%
#
# Epoch 16, Average Loss: 0.0728, Training Accuracy: 15.63%
#
# Epoch 17, Average Loss: 0.0784, Training Accuracy: 16.67%
#
# Epoch 18, Average Loss: 0.0768, Training Accuracy: 16.43%
#
# Epoch 19, Average Loss: 0.0719, Training Accuracy: 16.93%
#
# Epoch 20, Average Loss: 0.0785, Training Accuracy: 16.40%
#
# Epoch 21, Average Loss: 0.0714, Training Accuracy: 17.20%
#
# Epoch 22, Average Loss: 0.0777, Training Accuracy: 16.83%
#
# Epoch 23, Average Loss: 0.0780, Training Accuracy: 15.67%
#
# Epoch 24, Average Loss: 0.0728, Training Accuracy: 17.07%
#
# Epoch 25, Average Loss: 0.0794, Training Accuracy: 17.37%
#
# Epoch 26, Average Loss: 0.0732, Training Accuracy: 15.53%
#
# Epoch 27, Average Loss: 0.0729, Training Accuracy: 16.10%
#
# Epoch 28, Average Loss: 0.0735, Training Accuracy: 16.60%
#
# Epoch 29, Average Loss: 0.0787, Training Accuracy: 16.40%
#
# Epoch 30, Average Loss: 0.0873, Training Accuracy: 16.53%
#
# Epoch 31, Average Loss: 0.0786, Training Accuracy: 16.23%
#
# Epoch 32, Average Loss: 0.0888, Training Accuracy: 17.03%
#
# Epoch 33, Average Loss: 0.0811, Training Accuracy: 17.20%
#
# Epoch 34, Average Loss: 0.0753, Training Accuracy: 15.53%
#
# Epoch 35, Average Loss: 0.0734, Training Accuracy: 15.47%
#
# Epoch 36, Average Loss: 0.0704, Training Accuracy: 16.57%
#
# Epoch 37, Average Loss: 0.0801, Training Accuracy: 15.73%
#
# Epoch 38, Average Loss: 0.0765, Training Accuracy: 15.20%
#
# Epoch 39, Average Loss: 0.0737, Training Accuracy: 16.80%
#
# Epoch 40, Average Loss: 0.0791, Training Accuracy: 16.70%
#
# Epoch 41, Average Loss: 0.0717, Training Accuracy: 16.67%
#
# Epoch 42, Average Loss: 0.0763, Training Accuracy: 16.80%
#
# Epoch 43, Average Loss: 0.0719, Training Accuracy: 15.90%
#
# Epoch 44, Average Loss: 0.0770, Training Accuracy: 17.27%
#
# Epoch 45, Average Loss: 0.0718, Training Accuracy: 16.70%
#
# Epoch 46, Average Loss: 0.0766, Training Accuracy: 16.57%
#
# Epoch 47, Average Loss: 0.0736, Training Accuracy: 17.10%
#
# Epoch 48, Average Loss: 0.0811, Training Accuracy: 17.37%
#
# Epoch 49, Average Loss: 0.0772, Training Accuracy: 16.23%
#
# Epoch 50, Average Loss: 0.0802, Training Accuracy: 16.07%
# The Accuracy is: 16.666666666666664
# ------------------------------------------------------------
# Learning Rate: 0.1   Hidden Size: 100   Batch Size: 10
# Epoch 1, Average Loss: 0.1543, Training Accuracy: 36.20%
#
# Epoch 2, Average Loss: 0.1496, Training Accuracy: 40.70%
#
# Epoch 3, Average Loss: 0.1396, Training Accuracy: 45.90%
#
# Epoch 4, Average Loss: 0.1285, Training Accuracy: 49.50%
#
# Epoch 5, Average Loss: 0.1233, Training Accuracy: 52.47%
#
# Epoch 6, Average Loss: 0.1204, Training Accuracy: 53.27%
#
# Epoch 7, Average Loss: 0.1104, Training Accuracy: 57.13%
#
# Epoch 8, Average Loss: 0.1051, Training Accuracy: 59.40%
#
# Epoch 9, Average Loss: 0.1352, Training Accuracy: 44.87%
#
# Epoch 10, Average Loss: 0.1874, Training Accuracy: 17.97%
#
# Epoch 11, Average Loss: 0.1869, Training Accuracy: 17.17%
#
# Epoch 12, Average Loss: 0.1874, Training Accuracy: 16.37%
#
# Epoch 13, Average Loss: 0.1864, Training Accuracy: 18.40%
#
# Epoch 14, Average Loss: 0.1861, Training Accuracy: 16.67%
#
# Epoch 15, Average Loss: 0.1901, Training Accuracy: 16.17%
#
# Epoch 16, Average Loss: 0.1876, Training Accuracy: 16.40%
#
# Epoch 17, Average Loss: 0.1896, Training Accuracy: 14.83%
#
# Epoch 18, Average Loss: 0.1870, Training Accuracy: 17.00%
#
# Epoch 19, Average Loss: 0.1907, Training Accuracy: 16.80%
#
# Epoch 20, Average Loss: 0.1877, Training Accuracy: 16.73%
#
# Epoch 21, Average Loss: 0.1895, Training Accuracy: 16.10%
#
# Epoch 22, Average Loss: 0.1877, Training Accuracy: 16.37%
#
# Epoch 23, Average Loss: 0.1892, Training Accuracy: 17.07%
#
# Epoch 24, Average Loss: 0.1893, Training Accuracy: 16.63%
#
# Epoch 25, Average Loss: 0.1878, Training Accuracy: 16.13%
#
# Epoch 26, Average Loss: 0.1875, Training Accuracy: 16.97%
#
# Epoch 27, Average Loss: 0.1864, Training Accuracy: 16.17%
#
# Epoch 28, Average Loss: 0.1909, Training Accuracy: 16.13%
#
# Epoch 29, Average Loss: 0.1889, Training Accuracy: 17.13%
#
# Epoch 30, Average Loss: 0.1884, Training Accuracy: 16.63%
#
# Epoch 31, Average Loss: 0.1858, Training Accuracy: 17.57%
#
# Epoch 32, Average Loss: 0.1880, Training Accuracy: 16.07%
#
# Epoch 33, Average Loss: 0.1912, Training Accuracy: 16.37%
#
# Epoch 34, Average Loss: 0.1937, Training Accuracy: 16.40%
#
# Epoch 35, Average Loss: 0.1882, Training Accuracy: 15.60%
#
# Epoch 36, Average Loss: 0.1865, Training Accuracy: 16.73%
#
# Epoch 37, Average Loss: 0.1873, Training Accuracy: 15.53%
#
# Epoch 38, Average Loss: 0.1905, Training Accuracy: 16.60%
#
# Epoch 39, Average Loss: 0.1895, Training Accuracy: 16.70%
#
# Epoch 40, Average Loss: 0.1884, Training Accuracy: 17.07%
#
# Epoch 41, Average Loss: 0.1881, Training Accuracy: 17.67%
#
# Epoch 42, Average Loss: 0.1911, Training Accuracy: 15.77%
#
# Epoch 43, Average Loss: 0.1856, Training Accuracy: 15.73%
#
# Epoch 44, Average Loss: 0.1897, Training Accuracy: 17.20%
#
# Epoch 45, Average Loss: 0.1890, Training Accuracy: 15.83%
#
# Epoch 46, Average Loss: 0.1882, Training Accuracy: 16.47%
#
# Epoch 47, Average Loss: 0.1863, Training Accuracy: 15.93%
#
# Epoch 48, Average Loss: 0.1916, Training Accuracy: 16.47%
#
# Epoch 49, Average Loss: 0.1854, Training Accuracy: 17.33%
#
# Epoch 50, Average Loss: 0.1857, Training Accuracy: 16.93%
# The Accuracy is: 14.000000000000002
# ------------------------------------------------------------
# Learning Rate: 0.1   Hidden Size: 100   Batch Size: 30
# Epoch 1, Average Loss: 0.0521, Training Accuracy: 35.10%
#
# Epoch 2, Average Loss: 0.0507, Training Accuracy: 39.23%
#
# Epoch 3, Average Loss: 0.0486, Training Accuracy: 43.57%
#
# Epoch 4, Average Loss: 0.0481, Training Accuracy: 45.00%
#
# Epoch 5, Average Loss: 0.0447, Training Accuracy: 48.90%
#
# Epoch 6, Average Loss: 0.2306, Training Accuracy: 16.50%
#
# Epoch 7, Average Loss: 0.2879, Training Accuracy: 17.13%
#
# Epoch 8, Average Loss: 0.3219, Training Accuracy: 16.67%
#
# Epoch 9, Average Loss: 0.3030, Training Accuracy: 16.57%
#
# Epoch 10, Average Loss: 0.3164, Training Accuracy: 17.50%
#
# Epoch 11, Average Loss: 0.2867, Training Accuracy: 16.67%
#
# Epoch 12, Average Loss: 0.2665, Training Accuracy: 16.67%
#
# Epoch 13, Average Loss: 0.2410, Training Accuracy: 16.67%
#
# Epoch 14, Average Loss: 0.2380, Training Accuracy: 16.67%
#
# Epoch 15, Average Loss: 0.3225, Training Accuracy: 16.67%
#
# Epoch 16, Average Loss: 0.3532, Training Accuracy: 15.93%
#
# Epoch 17, Average Loss: 0.4093, Training Accuracy: 17.07%
#
# Epoch 18, Average Loss: 0.4113, Training Accuracy: 16.73%
#
# Epoch 19, Average Loss: 0.4386, Training Accuracy: 16.77%
#
# Epoch 20, Average Loss: 0.4479, Training Accuracy: 16.83%
#
# Epoch 21, Average Loss: 0.4456, Training Accuracy: 16.13%
#
# Epoch 22, Average Loss: 0.4502, Training Accuracy: 16.67%
#
# Epoch 23, Average Loss: 0.4428, Training Accuracy: 17.00%
#
# Epoch 24, Average Loss: 0.4676, Training Accuracy: 16.60%
#
# Epoch 25, Average Loss: 0.4539, Training Accuracy: 17.47%
#
# Epoch 26, Average Loss: 0.4739, Training Accuracy: 16.73%
#
# Epoch 27, Average Loss: 0.4734, Training Accuracy: 16.70%
#
# Epoch 28, Average Loss: 0.4488, Training Accuracy: 17.57%
#
# Epoch 29, Average Loss: 0.4504, Training Accuracy: 17.07%
#
# Epoch 30, Average Loss: 0.3948, Training Accuracy: 15.73%
#
# Epoch 31, Average Loss: 0.3701, Training Accuracy: 16.33%
#
# Epoch 32, Average Loss: 0.4195, Training Accuracy: 17.07%
#
# Epoch 33, Average Loss: 0.4181, Training Accuracy: 17.17%
#
# Epoch 34, Average Loss: 0.4080, Training Accuracy: 16.80%
#
# Epoch 35, Average Loss: 0.3928, Training Accuracy: 17.10%
#
# Epoch 36, Average Loss: 0.4150, Training Accuracy: 17.00%
#
# Epoch 37, Average Loss: 0.4108, Training Accuracy: 16.83%
#
# Epoch 38, Average Loss: 0.4126, Training Accuracy: 16.57%
#
# Epoch 39, Average Loss: 0.3892, Training Accuracy: 17.50%
#
# Epoch 40, Average Loss: 0.4299, Training Accuracy: 17.17%
#
# Epoch 41, Average Loss: 0.4024, Training Accuracy: 16.97%
#
# Epoch 42, Average Loss: 0.4160, Training Accuracy: 16.87%
#
# Epoch 43, Average Loss: 0.3944, Training Accuracy: 17.37%
#
# Epoch 44, Average Loss: 0.3817, Training Accuracy: 17.83%
#
# Epoch 45, Average Loss: 0.4153, Training Accuracy: 16.93%
#
# Epoch 46, Average Loss: 0.4131, Training Accuracy: 17.40%
#
# Epoch 47, Average Loss: 0.4312, Training Accuracy: 17.80%
#
# Epoch 48, Average Loss: 0.4247, Training Accuracy: 16.77%
#
# Epoch 49, Average Loss: 0.4360, Training Accuracy: 16.67%
#
# Epoch 50, Average Loss: 0.4389, Training Accuracy: 16.50%
# The Accuracy is: 16.666666666666664
# ------------------------------------------------------------

# %%
class RecurrentNeuralNetwork_2:
    def __init__(self, input_size, hidden_size, output_size, learning_rate):
        # parameters
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.output_size = output_size
        # Initialize weights
        self.W_IH = np.random.uniform(-0.1, 0.1, (hidden_size, input_size + 1))
        self.W_HH = np.random.uniform(-0.1, 0.1, (hidden_size, hidden_size))
        self.W_HO = np.random.uniform(-0.1, 0.1, (output_size, hidden_size + 1))

    @staticmethod
    def sigmoid(x):
        return 1 / (1 + np.exp(-x))

    @staticmethod
    def tanh(x):
        return np.tanh(x)

    @staticmethod
    def sigmoid_derivative(x):
        return x * (1 - x)

    @staticmethod
    def tanh_derivative(x):
        return 1 - x**2

    @staticmethod
    def cross_entropy(predictions, targets, epsilon=1e-12):
        predictions = np.clip(predictions, epsilon, 1. - epsilon)
        N = predictions.shape[0]
        ce = -np.sum(targets*np.log(predictions+epsilon))/N
        return ce

    def forward_pass(self, inputs): # Just used for evaluate, it already implemented in train method
      T, _ = inputs.shape
      self.H = np.zeros((T + 1, self.hidden_size))
      Y = np.zeros((T, self.output_size))

      for t in range(T):
          x = inputs[t]
          if x.ndim == 1:
              x = np.hstack([x, [1]])
          else:
              x = np.hstack([x, np.ones((x.shape[0], 1))])  # Add bias to each sample in the batch
          self.H[t] = self.tanh(np.dot(self.W_IH, x) + np.dot(self.W_HH, self.H[t-1]))
          y = self.sigmoid(np.dot(self.W_HO, np.hstack([self.H[t], [1]])))
          Y[t] = y

      return Y

    def train(self, train_x, train_y, epochs, batch_size, early_stopping=True, patience=6): # Patience value is for early stopping
      num_samples, sequence_length, num_features = train_x.shape
      _, num_classes = train_y.shape

      # Define 10% of training set as validation set
      val_size = int(0.1 * num_samples)
      val_indices = np.random.choice(num_samples, val_size, replace=False)
      train_indices = np.array([i for i in range(num_samples) if i not in val_indices])

      # Separating the validation set from the training set
      validation_x = train_x[val_indices]
      validation_y = train_y[val_indices]
      train_x = train_x[train_indices]
      train_y = train_y[train_indices]

      best_val_loss = float('inf')
      val_loss_increase_count = 0
      validation_losses = []

      for epoch in range(epochs):
          epoch_loss = 0
          correct_train_predictions = 0

          indices = np.arange(train_indices.shape[0])
          np.random.shuffle(indices)
          shuffled_train_x = train_x[indices]
          shuffled_train_y = train_y[indices]

          for i in range(0, train_indices.shape[0], batch_size):
              batch_end = min(i + batch_size, train_indices.shape[0])
              batch_inputs = shuffled_train_x[i:batch_end]
              batch_targets = shuffled_train_y[i:batch_end]

              # Reset gradients and hidden states
              dW_IH, dW_HH, dW_HO = np.zeros_like(self.W_IH), np.zeros_like(self.W_HH), np.zeros_like(self.W_HO)
              h_prev = np.zeros((self.hidden_size, 1))

              batch_loss = 0

              for t in range(sequence_length):
                  x = np.hstack([batch_inputs[:, t, :], np.ones((batch_end - i, 1))])  # Add bias term
                  y_true = batch_targets

                  # Forward pass
                  h_prev = np.tanh(np.dot(self.W_IH, x.T) + np.dot(self.W_HH, h_prev))
                  y_pred = self.sigmoid(np.dot(self.W_HO, np.vstack([h_prev, np.ones((1, batch_end - i))])))

                  if t == sequence_length - 1:  # Compute loss
                      batch_loss += np.sum(self.cross_entropy(y_pred.T, y_true))
                      correct_train_predictions += np.sum(np.argmax(y_pred, axis=0) == np.argmax(y_true, axis=1))

                  # BPTT
                  delta_o = (y_pred - y_true.T) * self.sigmoid_derivative(y_pred)
                  dW_HO += np.dot(delta_o, np.vstack([h_prev, np.ones((1, batch_end - i))]).T)
                  delta_h = np.dot(self.W_HO.T, delta_o)[:-1] * self.tanh_derivative(h_prev)

                  dW_HH += np.dot(delta_h, h_prev.T)
                  dW_IH += np.dot(delta_h, x)

              # Update weights after the batch
              self.W_IH -= self.learning_rate * dW_IH / sequence_length
              self.W_HH -= self.learning_rate * dW_HH / sequence_length
              self.W_HO -= self.learning_rate * dW_HO / sequence_length

              epoch_loss += batch_loss / (batch_end - i)

          # Average loss and accuracy
          epoch_loss /= (train_indices.shape[0] / batch_size)
          train_accuracy = correct_train_predictions / train_indices.shape[0]

          # Validation
          val_loss = 0
          correct_val_predictions = 0
          for i in range(0, val_size, batch_size):
              batch_end = min(i + batch_size, val_size)
              batch_inputs = validation_x[i:batch_end]
              batch_targets = validation_y[i:batch_end]

              # Perform forward pass for validation set
              h_prev = np.zeros((self.hidden_size, 1))
              for t in range(sequence_length):
                  x = np.hstack([batch_inputs[:, t, :], np.ones((batch_end - i, 1))])  # Add bias term
                  h_prev = np.tanh(np.dot(self.W_IH, x.T) + np.dot(self.W_HH, h_prev))
                  y_pred = self.sigmoid(np.dot(self.W_HO, np.vstack([h_prev, np.ones((1, batch_end - i))])))

                  if t == sequence_length - 1:  # Compute loss
                      val_loss += np.sum(self.cross_entropy(y_pred.T, batch_targets))

              correct_val_predictions += np.sum(np.argmax(y_pred, axis=0) == np.argmax(batch_targets, axis=1))

          val_loss /= val_size
          validation_losses.append(val_loss)
          val_accuracy = correct_val_predictions / val_size

          # Early stopping
          if early_stopping:
              if val_loss < best_val_loss:
                  best_val_loss = val_loss
                  val_loss_increase_count = 0
              else:
                  val_loss_increase_count += 1
                  if val_loss_increase_count >= patience:
                      print(f"Early stopping after epoch {epoch + 1}")
                      break

          # Print epoch stats
          print(f"Epoch {epoch + 1}, Training Loss: {epoch_loss:.4f}, Training Accuracy: {train_accuracy * 100:.2f}%, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy * 100:.2f}%")

      return best_val_loss, validation_losses

    def evaluate(self, test_x, test_y):
      total_loss = 0
      correct_predictions = 0
      class_correct = dict()
      class_total = dict()

      for i in range(len(test_x)):
          outputs = self.forward_pass(test_x[i])
          total_loss += self.cross_entropy(outputs[-1], test_y[i])
          predicted = np.argmax(outputs[-1])
          actual = np.argmax(test_y[i])

          correct_predictions += int(predicted == actual)

          if actual in class_correct:
              class_correct[actual] += int(predicted == actual)
          else:
              class_correct[actual] = int(predicted == actual)

          if actual in class_total:
              class_total[actual] += 1
          else:
              class_total[actual] = 1

      average_loss = total_loss / len(test_x)
      accuracy = correct_predictions / len(test_x) * 100

      per_class_accuracy = {cls: class_correct[cls] / class_total[cls] * 100 for cls in class_correct}

      return average_loss, accuracy, per_class_accuracy

# %%
# RNN
input_size = 3
output_size = 6

learning_rate = 0.05
hidden_size = 50
batch_sizes = [10,30]
epochs = 50

for batch_size in batch_sizes:
  print('Learning Rate:', learning_rate , ' ' , 'Hidden Size:', hidden_size , ' ' ,'Batch Size:', batch_size)
  rnn_2 = RecurrentNeuralNetwork_2(input_size, hidden_size, output_size, learning_rate)
  rnn_2.train(training_x, training_y, epochs, batch_size)
  _, accuracy, per_class_accuracy = rnn_2.evaluate(test_x, test_y)
  print(f'The Accuracy is: {accuracy}')
  plot_per_class_accuracy(per_class_accuracy)
  print('------------------------------------------------------------')
# Out:
# Learning Rate: 0.05   Hidden Size: 50   Batch Size: 10
# Epoch 1, Training Loss: 0.1513, Training Accuracy: 32.85%, Validation Loss: 0.1561, Validation Accuracy: 39.00%
# Epoch 2, Training Loss: 0.1473, Training Accuracy: 39.81%, Validation Loss: 0.1424, Validation Accuracy: 40.00%
# Epoch 3, Training Loss: 0.1423, Training Accuracy: 43.52%, Validation Loss: 0.1429, Validation Accuracy: 44.67%
# Epoch 4, Training Loss: 0.1387, Training Accuracy: 43.93%, Validation Loss: 0.1275, Validation Accuracy: 45.00%
# Epoch 5, Training Loss: 0.1327, Training Accuracy: 45.89%, Validation Loss: 0.1254, Validation Accuracy: 50.33%
# Epoch 6, Training Loss: 0.1283, Training Accuracy: 48.15%, Validation Loss: 0.1329, Validation Accuracy: 47.33%
# Epoch 7, Training Loss: 0.1230, Training Accuracy: 49.59%, Validation Loss: 0.1147, Validation Accuracy: 53.67%
# Epoch 8, Training Loss: 0.1187, Training Accuracy: 51.63%, Validation Loss: 0.1126, Validation Accuracy: 54.67%
# Epoch 9, Training Loss: 0.1136, Training Accuracy: 54.04%, Validation Loss: 0.1154, Validation Accuracy: 55.00%
# Epoch 10, Training Loss: 0.1089, Training Accuracy: 55.26%, Validation Loss: 0.1070, Validation Accuracy: 57.67%
# Epoch 11, Training Loss: 0.1070, Training Accuracy: 55.85%, Validation Loss: 0.1050, Validation Accuracy: 54.67%
# Epoch 12, Training Loss: 0.1018, Training Accuracy: 59.93%, Validation Loss: 0.1200, Validation Accuracy: 47.33%
# Epoch 13, Training Loss: 0.0960, Training Accuracy: 60.96%, Validation Loss: 0.0878, Validation Accuracy: 64.33%
# Epoch 14, Training Loss: 0.0951, Training Accuracy: 61.74%, Validation Loss: 0.0904, Validation Accuracy: 60.00%
# Epoch 15, Training Loss: 0.0910, Training Accuracy: 62.89%, Validation Loss: 0.0922, Validation Accuracy: 57.67%
# Epoch 16, Training Loss: 0.0899, Training Accuracy: 63.85%, Validation Loss: 0.0896, Validation Accuracy: 65.00%
# Epoch 17, Training Loss: 0.0894, Training Accuracy: 65.26%, Validation Loss: 0.0912, Validation Accuracy: 65.33%
# Epoch 18, Training Loss: 0.0884, Training Accuracy: 64.52%, Validation Loss: 0.0868, Validation Accuracy: 63.33%
# Epoch 19, Training Loss: 0.0876, Training Accuracy: 64.93%, Validation Loss: 0.0892, Validation Accuracy: 64.00%
# Epoch 20, Training Loss: 0.0844, Training Accuracy: 67.59%, Validation Loss: 0.0867, Validation Accuracy: 66.00%
# Epoch 21, Training Loss: 0.0857, Training Accuracy: 66.81%, Validation Loss: 0.0866, Validation Accuracy: 69.33%
# Epoch 22, Training Loss: 0.0839, Training Accuracy: 67.78%, Validation Loss: 0.0870, Validation Accuracy: 63.33%
# Epoch 23, Training Loss: 0.0846, Training Accuracy: 66.52%, Validation Loss: 0.0810, Validation Accuracy: 67.67%
# Epoch 24, Training Loss: 0.0830, Training Accuracy: 68.00%, Validation Loss: 0.0802, Validation Accuracy: 68.33%
# Epoch 25, Training Loss: 0.0814, Training Accuracy: 68.30%, Validation Loss: 0.1018, Validation Accuracy: 59.33%
# Epoch 26, Training Loss: 0.0827, Training Accuracy: 68.30%, Validation Loss: 0.0847, Validation Accuracy: 67.33%
# Epoch 27, Training Loss: 0.0820, Training Accuracy: 68.89%, Validation Loss: 0.0908, Validation Accuracy: 63.67%
# Epoch 28, Training Loss: 0.0853, Training Accuracy: 67.89%, Validation Loss: 0.0850, Validation Accuracy: 66.33%
# Epoch 29, Training Loss: 0.0858, Training Accuracy: 66.89%, Validation Loss: 0.0899, Validation Accuracy: 65.67%
# Epoch 30, Training Loss: 0.0859, Training Accuracy: 67.11%, Validation Loss: 0.0798, Validation Accuracy: 70.33%
# Epoch 31, Training Loss: 0.0883, Training Accuracy: 66.89%, Validation Loss: 0.0938, Validation Accuracy: 65.67%
# Epoch 32, Training Loss: 0.0902, Training Accuracy: 66.70%, Validation Loss: 0.1156, Validation Accuracy: 57.33%
# Epoch 33, Training Loss: 0.0870, Training Accuracy: 67.48%, Validation Loss: 0.0820, Validation Accuracy: 68.33%
# Epoch 34, Training Loss: 0.0834, Training Accuracy: 68.48%, Validation Loss: 0.0957, Validation Accuracy: 67.67%
# Epoch 35, Training Loss: 0.0851, Training Accuracy: 68.41%, Validation Loss: 0.0759, Validation Accuracy: 71.00%
# Epoch 36, Training Loss: 0.0822, Training Accuracy: 68.74%, Validation Loss: 0.0920, Validation Accuracy: 63.67%
# Epoch 37, Training Loss: 0.0821, Training Accuracy: 69.11%, Validation Loss: 0.0834, Validation Accuracy: 70.00%
# Epoch 38, Training Loss: 0.0823, Training Accuracy: 69.70%, Validation Loss: 0.0839, Validation Accuracy: 69.00%
# Epoch 39, Training Loss: 0.0825, Training Accuracy: 68.67%, Validation Loss: 0.0948, Validation Accuracy: 66.33%
# Epoch 40, Training Loss: 0.0828, Training Accuracy: 69.37%, Validation Loss: 0.0836, Validation Accuracy: 68.33%
# Early stopping after epoch 41
# The Accuracy is: 63.33333333333333
# ------------------------------------------------------------
# Learning Rate: 0.05   Hidden Size: 50   Batch Size: 30
# Epoch 1, Training Loss: 0.0505, Training Accuracy: 32.74%, Validation Loss: 0.0555, Validation Accuracy: 31.67%
# Epoch 2, Training Loss: 0.0500, Training Accuracy: 39.22%, Validation Loss: 0.0508, Validation Accuracy: 42.67%
# Epoch 3, Training Loss: 0.0490, Training Accuracy: 40.78%, Validation Loss: 0.0491, Validation Accuracy: 42.33%
# Epoch 4, Training Loss: 0.0477, Training Accuracy: 42.56%, Validation Loss: 0.0516, Validation Accuracy: 43.67%
# Epoch 5, Training Loss: 0.0466, Training Accuracy: 44.44%, Validation Loss: 0.0459, Validation Accuracy: 42.67%
# Epoch 6, Training Loss: 0.0464, Training Accuracy: 45.78%, Validation Loss: 0.0481, Validation Accuracy: 45.33%
# Epoch 7, Training Loss: 0.0452, Training Accuracy: 47.30%, Validation Loss: 0.0452, Validation Accuracy: 45.33%
# Epoch 8, Training Loss: 0.0433, Training Accuracy: 48.22%, Validation Loss: 0.0459, Validation Accuracy: 44.33%
# Epoch 9, Training Loss: 0.0427, Training Accuracy: 49.44%, Validation Loss: 0.0434, Validation Accuracy: 48.00%
# Epoch 10, Training Loss: 0.0422, Training Accuracy: 51.37%, Validation Loss: 0.0412, Validation Accuracy: 50.33%
# Epoch 11, Training Loss: 0.0415, Training Accuracy: 52.07%, Validation Loss: 0.0419, Validation Accuracy: 47.33%
# Epoch 12, Training Loss: 0.0411, Training Accuracy: 52.93%, Validation Loss: 0.0438, Validation Accuracy: 51.33%
# Epoch 13, Training Loss: 0.0411, Training Accuracy: 54.11%, Validation Loss: 0.0472, Validation Accuracy: 51.67%
# Epoch 14, Training Loss: 0.0405, Training Accuracy: 55.04%, Validation Loss: 0.0401, Validation Accuracy: 54.67%
# Epoch 15, Training Loss: 0.0392, Training Accuracy: 55.56%, Validation Loss: 0.0378, Validation Accuracy: 51.67%
# Epoch 16, Training Loss: 0.0370, Training Accuracy: 58.59%, Validation Loss: 0.0365, Validation Accuracy: 57.67%
# Epoch 17, Training Loss: 0.0364, Training Accuracy: 58.56%, Validation Loss: 0.0354, Validation Accuracy: 62.33%
# Epoch 18, Training Loss: 0.0345, Training Accuracy: 61.26%, Validation Loss: 0.0331, Validation Accuracy: 60.33%
# Epoch 19, Training Loss: 0.0337, Training Accuracy: 61.11%, Validation Loss: 0.0439, Validation Accuracy: 45.33%
# Epoch 20, Training Loss: 0.0322, Training Accuracy: 63.07%, Validation Loss: 0.0344, Validation Accuracy: 53.00%
# Epoch 21, Training Loss: 0.0307, Training Accuracy: 64.04%, Validation Loss: 0.0269, Validation Accuracy: 66.67%
# Epoch 22, Training Loss: 0.0300, Training Accuracy: 64.85%, Validation Loss: 0.0259, Validation Accuracy: 62.67%
# Epoch 23, Training Loss: 0.0280, Training Accuracy: 67.15%, Validation Loss: 0.0289, Validation Accuracy: 68.67%
# Epoch 24, Training Loss: 0.0280, Training Accuracy: 66.33%, Validation Loss: 0.0286, Validation Accuracy: 66.00%
# Epoch 25, Training Loss: 0.0298, Training Accuracy: 65.41%, Validation Loss: 0.0297, Validation Accuracy: 66.33%
# Epoch 26, Training Loss: 0.0270, Training Accuracy: 66.74%, Validation Loss: 0.0313, Validation Accuracy: 69.67%
# Epoch 27, Training Loss: 0.0283, Training Accuracy: 67.56%, Validation Loss: 0.0278, Validation Accuracy: 68.67%
# Early stopping after epoch 28
# The Accuracy is: 53.666666666666664
# ------------------------------------------------------------
